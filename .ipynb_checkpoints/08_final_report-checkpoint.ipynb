# %%
import sys
sys.path.append('src')
from plot_style import set_publication_style
set_publication_style()

# %%
import seaborn as sns
palette = sns.color_palette("colorblind") # built-in, colorblind-tested
# or, for continuous data (heatmaps): 'viridis' or 'cividis' instead of 'coolwarm'/'jet'
sns.set_palette(palette)

# %%
FIG_WIDTH_SINGLE = 3.35
FIG_WIDTH_DOUBLE = 7.0
