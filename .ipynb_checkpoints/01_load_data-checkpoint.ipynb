# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/mock_ige_cytokine_behavior.csv')
df.head()
# Out:
#   subject_id  age sex  IgE_IU_mL  IL4_pg_mL  IL6_pg_mL  IL10_pg_mL  \
# 0       S001    4   F      54.47       4.71       3.40        5.35
# 1       S002    6   F      34.05       3.49       3.72        2.04
# 2       S003   11   F      42.36       8.27       2.53        5.84
# 3       S004    7   M     122.89      13.42       7.12         NaN
# 4       S005   10   M      30.87       3.87       1.96        3.90
#
#    TNFa_pg_mL  IFNg_pg_mL  behavior_score behavior_group
# 0        1.88        3.11            24.0       Atypical
# 1        1.23        1.99            13.4        Typical
# 2        1.95        2.66            39.4       Atypical
# 3        6.24        5.43            19.6       Atypical
# 4        1.39        2.64            22.4       Atypical

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   subject_id      150 non-null    object
#  1   age             150 non-null    int64
#  2   sex             150 non-null    object
#  3   IgE_IU_mL       150 non-null    float64
#  4   IL4_pg_mL       150 non-null    float64
#  5   IL6_pg_mL       150 non-null    float64
#  6   IL10_pg_mL      145 non-null    float64
#  7   TNFa_pg_mL      145 non-null    float64
#  8   IFNg_pg_mL      150 non-null    float64
#  9   behavior_score  150 non-null    float64
#  10  behavior_group  150 non-null    object
# dtypes: float64(7), int64(1), object(3)
# memory usage: 13.0+ KB

# %%
df.isnull().sum()
# Out:
# subject_id        0
# age               0
# sex               0
# IgE_IU_mL         0
# IL4_pg_mL         0
# IL6_pg_mL         0
# IL10_pg_mL        5
# TNFa_pg_mL        5
# IFNg_pg_mL        0
# behavior_score    0
# behavior_group    0
# dtype: int64
